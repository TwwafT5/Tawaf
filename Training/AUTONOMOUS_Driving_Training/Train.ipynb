# %% [markdown]
# # Data preprocess

# %%
import pandas as pd
df1 = pd.read_csv('22Nov608/log_0.csv', names=['img','steering', 'throttle'])
df2 = pd.read_csv('22Nov608/log_1.csv', names=['img','steering', 'throttle'])
df = pd.concat([df1,df2])
remove_list = ['/home/pi/selfDriving_wheelchair/data/ROUND0','/home/pi/selfDriving_wheelchair/data/ROUND1']
for r in remove_list:
    for i in range(len(df.iloc[:,0])):
        df.iloc[i, 0] = df.iloc[i,0].replace(r,'IMG')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10953 entries, 0 to 6569
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   img       10953 non-null  object
#  1   steering  10953 non-null  float64
#  2   throttle  10953 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 342.3+ KB

# %%
import pandas as pd
df = pd.read_csv('23Nov959/log_0.csv', names=['img','steering', 'throttle'])

for i in range(len(df.iloc[:,0])):
    df.iloc[i, 0] = df.iloc[i,0].replace('/home/pi/selfDriving_wheelchair/data/ROUND0','IMG')

df.head(10)
# Out:
#                               img  steering  throttle
# 0   IMG/Image_170072212088316.jpg   0.03418  -0.41029
# 1  IMG/Image_1700722120990053.jpg   0.02564  -0.52141
# 2  IMG/Image_1700722120998727.jpg   0.03418  -0.52995
# 3  IMG/Image_1700722121011197.jpg   0.03418  -0.52995
# 4  IMG/Image_1700722121019243.jpg   0.03418  -0.52995
# 5   IMG/Image_170072212103716.jpg   0.03418  -0.52995
# 6  IMG/Image_1700722121068452.jpg   0.03418  -0.63253
# 7  IMG/Image_1700722121102083.jpg   0.03418  -0.63253
# 8  IMG/Image_1700722121138567.jpg   0.03418  -0.79492
# 9  IMG/Image_1700722121168202.jpg   0.03418  -0.79492

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16732 entries, 0 to 16731
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   img       16732 non-null  object
#  1   steering  16732 non-null  float64
#  2   throttle  16732 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 392.3+ KB

# %%
df.to_csv('23Nov959/data.csv',index=False)

# %%
for i in range(len(df1.iloc[:,0])):
    df1.iloc[i, 0] = df1.iloc[i,0].replace('/home/pi/selfDriving_wheelchair/data/ROUND0','IMG')

df1.head()
# Out:
#                               img  steering  throttle
# 0  IMG/Image_1700564937334195.jpg   -0.2992      -1.0
# 1   IMG/Image_170056493734836.jpg    0.4615      -1.0
# 2  IMG/Image_1700564937365122.jpg    0.4615      -1.0
# 3  IMG/Image_1700564937386723.jpg    0.4615      -1.0
# 4  IMG/Image_1700564937437555.jpg    0.4615      -1.0

# %%
import pandas as pd
df2 = pd.read_csv('data_dashed/log_1.csv', names=['img','steering', 'throttle'])
df2.head()
# Out:
#                                                  img  steering  throttle
# 0  /home/pi/selfDriving_wheelchair/data/ROUND1/Im...   -0.0940      -1.0
# 1  /home/pi/selfDriving_wheelchair/data/ROUND1/Im...    0.2735      -1.0
# 2  /home/pi/selfDriving_wheelchair/data/ROUND1/Im...    0.2735      -1.0
# 3  /home/pi/selfDriving_wheelchair/data/ROUND1/Im...    0.0000      -1.0
# 4  /home/pi/selfDriving_wheelchair/data/ROUND1/Im...    0.0000      -1.0

# %%
for i in range(len(df2.iloc[:,0])):
    df2.iloc[i, 0] = df2.iloc[i,0].replace('/home/pi/selfDriving_wheelchair/data/ROUND1','IMG')

df2.head()
# Out:
#                               img  steering  throttle
# 0  IMG/Image_1700565131969178.jpg   -0.0940      -1.0
# 1  IMG/Image_1700565131982469.jpg    0.2735      -1.0
# 2  IMG/Image_1700565132019651.jpg    0.2735      -1.0
# 3  IMG/Image_1700565132035815.jpg    0.0000      -1.0
# 4  IMG/Image_1700565132069433.jpg    0.0000      -1.0

# %%
import pandas as pd
df3 = pd.read_csv('data_dashed/log_2.csv', names=['img','steering', 'throttle'])
df3.head()
# Out:
#                                                  img  steering  throttle
# 0  /home/pi/selfDriving_wheelchair/data/ROUND2/Im...    0.0598      -1.0
# 1  /home/pi/selfDriving_wheelchair/data/ROUND2/Im...    0.4017      -1.0
# 2  /home/pi/selfDriving_wheelchair/data/ROUND2/Im...    0.4017      -1.0
# 3  /home/pi/selfDriving_wheelchair/data/ROUND2/Im...    0.4017      -1.0
# 4  /home/pi/selfDriving_wheelchair/data/ROUND2/Im...    0.4017      -1.0

# %%
for i in range(len(df3.iloc[:,0])):
    df3.iloc[i, 0] = df3.iloc[i,0].replace('/home/pi/selfDriving_wheelchair/data/ROUND2','IMG')

df3.head()
# Out:
#                               img  steering  throttle
# 0  IMG/Image_1700565501492849.jpg    0.0598      -1.0
# 1  IMG/Image_1700565501530541.jpg    0.4017      -1.0
# 2  IMG/Image_1700565501552125.jpg    0.4017      -1.0
# 3  IMG/Image_1700565501564274.jpg    0.4017      -1.0
# 4  IMG/Image_1700565501589678.jpg    0.4017      -1.0

# %%
df = pd.concat([df1,df2,df3])
df.head()
# Out:
#                               img  steering  throttle
# 0  IMG/Image_1700564937334195.jpg   -0.2992      -1.0
# 1   IMG/Image_170056493734836.jpg    0.4615      -1.0
# 2  IMG/Image_1700564937365122.jpg    0.4615      -1.0
# 3  IMG/Image_1700564937386723.jpg    0.4615      -1.0
# 4  IMG/Image_1700564937437555.jpg    0.4615      -1.0

# %%
df1.to_csv('data_dashed/data.csv',index=False)

# %% [markdown]
# # Load and split the data

# %%
import pandas as pd
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle


csv_path = 'DATA2K/data.csv'
data_df = pd.read_csv(csv_path)

data_df = shuffle(data_df)

train_df, validation_df = train_test_split(data_df, test_size=0.2)

# %%
img_height, img_width = 180, 180

def load_and_preprocess_img(img_path):
    path = 'DATA2k/'+img_path
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.bitwise_not(img)
    img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 15, -5)
    
    img = cv2.resize(img, (img_width, img_height))
    img = img / 255.0 
    return img

train_images = np.array([load_and_preprocess_img(path) for path in train_df['img']])
train_steering = np.array(train_df['steering'])
train_throttle = np.array(train_df['throttle'])
validation_images = np.array([load_and_preprocess_img(path) for path in validation_df['img']])
validation_steering = np.array(validation_df['steering'])
validation_throttle = np.array(validation_df['throttle'])

# %% [markdown]
# # 1st model architecture

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, History
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dense, MaxPooling2D

input_layer = Input(shape=(img_height, img_width, 3))
x = Conv2D(24, (5, 5), strides=(2, 2), activation='relu')(input_layer)
x = Conv2D(36, (5, 5), strides=(2, 2), activation='relu')(x)
x = Conv2D(48, (5, 5), strides=(2, 2), activation='relu')(x)
x = Flatten()(x)
x = Dense(100, activation='relu')(x)

steering_output = Dense(1, activation='linear', name='steering_output')(x)

throttle_output = Dense(1, activation='linear', name='throttle_output')(x)

model = Model(inputs=input_layer, outputs=[steering_output, throttle_output])

model.compile(optimizer='adam', loss={'steering_output': 'mse', 'throttle_output': 'mse'})

checkpoint_path = 'model_checkpoints/model_checkpoint_{epoch:02d}.h5'
checkpoint_callback = ModelCheckpoint(checkpoint_path, save_freq='epoch', verbose=1)
history_callback = History()


history = model.fit(train_images, {'steering_output': train_steering, 'throttle_output': train_throttle}, epochs=100,
          validation_data=(validation_images, {'steering_output': validation_steering, 'throttle_output': validation_throttle}),
          callbacks=[checkpoint_callback, history_callback])

loss = model.evaluate(validation_images, {'steering_output': validation_steering, 'throttle_output': validation_throttle})
print(f'Mean Squared Error on Validation Data (Steering): {loss[1]}, Throttle: {loss[2]}')

model.save('steering_throttle_model.h5')
# Out:
# Epoch 1/100
# 50/50 [==============================] - ETA: 0s - loss: 0.1996 - steering_output_loss: 0.1075 - throttle_output_loss: 0.0920
# Epoch 1: saving model to model_checkpoints\model_checkpoint_01.h5
# 50/50 [==============================] - 5s 83ms/step - loss: 0.1996 - steering_output_loss: 0.1075 - throttle_output_loss: 0.0920 - val_loss: 0.1052 - val_steering_output_loss: 0.0893 - val_throttle_output_loss: 0.0159
# Epoch 2/100
#  2/50 [>.............................] - ETA: 3s - loss: 0.1580 - steering_output_loss: 0.1371 - throttle_output_loss: 0.0210
# c:\Users\aanas\anaconda3\envs\tens\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 6))

plt.subplot(1, 3, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 2)
plt.plot(history.history['steering_output_loss'])
plt.plot(history.history['val_steering_output_loss'])
plt.title('Steering Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 3)
plt.plot(history.history['throttle_output_loss'])
plt.plot(history.history['val_throttle_output_loss'])
plt.title('Throttle Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

model = load_model('modelP.h5')


def preprocess_single_image(img_path):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
    img = cv2.resize(img, (img_width, img_height))
    img = img / 255.0 
    return np.expand_dims(img, axis=0)  

single_image_path = 'Image_1699881576618.jpg'

preprocessed_image = preprocess_single_image(single_image_path)

steering_prediction, throttle_prediction = model.predict(preprocessed_image)

print(f"Predicted Steering Value: {steering_prediction[0][0]}")
print(f"Predicted Throttle Value: {throttle_prediction[0][0]}")

# %% [markdown]
# # 2nd model architecture

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, History
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dense, MaxPooling2D, BatchNormalization

input_layer = Input(shape=(180, 180, 1))
x = Conv2D(24, (5, 5), strides=(2, 2), activation='relu')(input_layer)
x = MaxPooling2D((2, 2), padding="same")(x)
x = Conv2D(36, (5, 5), strides=(2, 2), activation='relu')(x)
x = MaxPooling2D((2, 2), padding="same")(x)
x = BatchNormalization()(x)
x = Conv2D(48, (5, 5), strides=(2, 2), activation='relu')(x)
x = MaxPooling2D((2, 2), padding="same")(x)
x = Flatten()(x)
x = Dense(100, activation='relu')(x)

steering_output = Dense(1, activation='linear', name='steering_output')(x)

throttle_output = Dense(1, activation='linear', name='throttle_output')(x)

model = Model(inputs=input_layer, outputs=[steering_output, throttle_output])

model.compile(optimizer='adam', loss={'steering_output': 'mse', 'throttle_output': 'mse'})

checkpoint_path = 'model_checkpoints/model_checkpoint_{epoch:02d}.h5'
checkpoint_callback = ModelCheckpoint(checkpoint_path, save_freq='epoch', verbose=1)
history_callback = History()


history = model.fit(train_images, {'steering_output': train_steering, 'throttle_output': train_throttle}, epochs=100,
          validation_data=(validation_images, {'steering_output': validation_steering, 'throttle_output': validation_throttle}),
          callbacks=[checkpoint_callback, history_callback])

loss = model.evaluate(validation_images, {'steering_output': validation_steering, 'throttle_output': validation_throttle})
print(f'Mean Squared Error on Validation Data (Steering): {loss[1]}, Throttle: {loss[2]}')

model.save('steering_throttle_model1.h5')
# Out:
# Epoch 1/100
# 69/70 [============================>.] - ETA: 0s - loss: 0.2382 - steering_output_loss: 0.1361 - throttle_output_loss: 0.1021
# Epoch 1: saving model to model_checkpoints\model_checkpoint_01.h5
# 70/70 [==============================] - 3s 40ms/step - loss: 0.2364 - steering_output_loss: 0.1350 - throttle_output_loss: 0.1015 - val_loss: 0.4492 - val_steering_output_loss: 0.0909 - val_throttle_output_loss: 0.3583
# Epoch 2/100
#  5/70 [=>............................] - ETA: 2s - loss: 0.0563 - steering_output_loss: 0.0342 - throttle_output_loss: 0.0220
# c:\Users\aanas\anaconda3\envs\tens\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ...

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# Load the pre-trained model
model = load_model('steering_throttle_model1.h5')

# Function to preprocess a single image
def preprocess_single_img(img_path):
    img = cv2.imread(img_path)
    img_np = np.asarray(img)

    print("img_np.shape: ", img_np.shape)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.bitwise_not(img)
    img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 15, -2)
    img = cv2.resize(img, (img_width, img_height))
    img = img / 255.0
    img = np.expand_dims(img, axis=-1)  # Add channel dimension
    return img

# Path to the image you want to predict on
image_path = 'test1.jpg'

# Preprocess the image
input_image = preprocess_single_img(image_path)

# Make prediction
steering_pred, throttle_pred = model.predict(np.array([input_image]))

# Print the predictions
print(f'Predicted Steering: {steering_pred[0][0]}')
print(f'Predicted Throttle: {throttle_pred[0][0]}')
# Out:
# img_np.shape:  (180, 240, 3)
# 1/1 [==============================] - 0s 43ms/step
# Predicted Steering: -0.5381084680557251
# Predicted Throttle: -1.0604835748672485

# %%
import tensorflow
tensorflow.__version__
# Out:
# '2.14.0'

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 6))

plt.subplot(1, 3, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 2)
plt.plot(history.history['steering_output_loss'])
plt.plot(history.history['val_steering_output_loss'])
plt.title('Steering Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 3)
plt.plot(history.history['throttle_output_loss'])
plt.plot(history.history['val_throttle_output_loss'])
plt.title('Throttle Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 6))

plt.subplot(1, 3, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 2)
plt.plot(history.history['steering_output_loss'])
plt.plot(history.history['val_steering_output_loss'])
plt.title('Steering Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 3)
plt.plot(history.history['throttle_output_loss'])
plt.plot(history.history['val_throttle_output_loss'])
plt.title('Throttle Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 3rd model architecture

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, History
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dense, MaxPooling2D, BatchNormalization

input_layer = Input(shape=(img_height, img_width, 3))
x = Conv2D(24, (5, 5), strides=(2, 2), activation='relu')(input_layer)
x = MaxPooling2D((2, 2), padding="same")(x)
x = Conv2D(36, (5, 5), strides=(2, 2), activation='relu')(x)
x = MaxPooling2D((2, 2), padding="same")(x)
x = BatchNormalization()(x)
x = Conv2D(48, (5, 5), strides=(2, 2), activation='relu')(x)
x = MaxPooling2D((2, 2), padding="same")(x)
x = Flatten()(x)
x = Dense(100, activation='relu')(x)

steering_output = Dense(1, activation='linear', name='steering_output')(x)

throttle_output = Dense(1, activation='linear', name='throttle_output')(x)

model = Model(inputs=input_layer, outputs=[steering_output, throttle_output])

model.compile(optimizer='adam', loss={'steering_output': 'mse', 'throttle_output': 'mse'})

checkpoint_path = 'model_checkpoints/model_checkpoint_{epoch:02d}.h5'
checkpoint_callback = ModelCheckpoint(checkpoint_path, save_freq='epoch', verbose=1)
history_callback = History()


history = model.fit(train_images, {'steering_output': train_steering, 'throttle_output': train_throttle}, epochs=70,
          validation_data=(validation_images, {'steering_output': validation_steering, 'throttle_output': validation_throttle}),
          callbacks=[checkpoint_callback, history_callback])

loss = model.evaluate(validation_images, {'steering_output': validation_steering, 'throttle_output': validation_throttle})
print(f'Mean Squared Error on Validation Data (Steering): {loss[1]}, Throttle: {loss[2]}')

model.save('steering_throttle_model2.h5')
# Out:
# Epoch 1/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.1746 - steering_output_loss: 0.1194 - throttle_output_loss: 0.0552
# Epoch 1: saving model to model_checkpoints\model_checkpoint_01.h5
# 50/50 [==============================] - 3s 49ms/step - loss: 0.1750 - steering_output_loss: 0.1203 - throttle_output_loss: 0.0547 - val_loss: 0.2281 - val_steering_output_loss: 0.1108 - val_throttle_output_loss: 0.1173
# Epoch 2/70
#  3/50 [>.............................] - ETA: 2s - loss: 0.1112 - steering_output_loss: 0.0711 - throttle_output_loss: 0.0402
# c:\Users\aanas\anaconda3\envs\tens\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 6))

plt.subplot(1, 3, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 2)
plt.plot(history.history['steering_output_loss'])
plt.plot(history.history['val_steering_output_loss'])
plt.title('Steering Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 3)
plt.plot(history.history['throttle_output_loss'])
plt.plot(history.history['val_throttle_output_loss'])
plt.title('Throttle Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Predict realtime on webcam

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

model = load_model('steering_throttle_model2.h5')
def preprocess_image(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
    img = cv2.resize(img, (img_width, img_height))
    img = img / 255.0  
    return np.expand_dims(img, axis=0)  
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    ret, frame = cap.read()
    preprocessed_image = preprocess_image(frame)

    steering_prediction, throttle_prediction = model.predict(preprocessed_image)

    print(f"Predicted Steering Value: {steering_prediction[0][0]}")
    print(f"Predicted Throttle Value: {throttle_prediction[0][0]}")
    print('-'*40)
    if not ret:
        print("Error: Failed to capture frame.")
        break

    cv2.imshow('Webcam Real-Time', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 49ms/step
# Predicted Steering Value: -0.4663822650909424
# Predicted Throttle Value: -1.1531097888946533
# ----------------------------------------
# 1/1 [==============================] - 0s 14ms/step
# Predicted Steering Value: -0.48492175340652466
# Predicted Throttle Value: -1.1264538764953613
# ----------------------------------------
# 1/1 [==============================] - 0s 14ms/step
# Predicted Steering Value: -0.5503613948822021
# Predicted Throttle Value: -1.136283278465271
# ----------------------------------------
# 1/1 [==============================] - 0s 14ms/step
# Predicted Steering Value: -0.5503613948822021
# Predicted Throttle Value: -1.136283278465271
# ----------------------------------------
# 1/1 [==============================] - 0s 14ms/step
# Predicted Steering Value: -0.5656707882881165
# Predicted Throttle Value: -1.1366592645645142
# ----------------------------------------
# ...

# %% [markdown]
# # Image Processing:

# %%
import cv2
import os

def preProcess(img):
    img = img[54:120,:,:]
    img = cv2.cvtColor(img, cv2.COLOR_RGB2YUV)
    img = cv2.GaussianBlur(img,  (3, 3), 0)
    img = cv2.resize(img, (200, 66))
    img = img/255

    
    return img

path = 'data/IMG3'
for name in os.listdir('data/IMG3'):
    filename = os.path.join(path,name)
    img = cv2.imread(filename)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.GaussianBlur(img,  (19, 19), 5)
    gray = cv2.bitwise_not(img)
    bw = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, \
                                cv2.THRESH_BINARY, 15, -2)
    cv2.imshow('processed image', bw)
    key = cv2.waitKey(0)
    if key == ord("q"):
        cv2.destroyAllWindows()
        break

cv2.destroyAllWindows()

# %% [markdown]
# # From course

# %%
import pandas as pd

data = pd.read_csv('23Nov959/data.csv')
data.tail(10)
# Out:
#                                   img  steering  throttle
# 15496  IMG/Image_1700722675109781.jpg  -0.24787  -0.72652
# 15497  IMG/Image_1700722675143314.jpg  -0.24787  -0.72652
# 15498  IMG/Image_1700722675176277.jpg  -0.33335  -0.73507
# 15499  IMG/Image_1700722675209783.jpg  -0.33335  -0.73507
# 15500   IMG/Image_170072267524273.jpg  -0.27354  -0.73507
# 15501  IMG/Image_1700722675276112.jpg  -0.27354  -0.73507
# 15502  IMG/Image_1700722675310013.jpg  -0.18806  -0.73507
# 15503  IMG/Image_1700722675343279.jpg  -0.18806  -0.73507
# 15504  IMG/Image_1700722675376254.jpg  -0.18806  -0.73507
# 15505  IMG/Image_1700722675409972.jpg  -0.18806  -0.73507

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.utils import shuffle

def balanceData(data,display=True):
    nBin = 31
    samplesPerBin =  1700
    hist, bins = np.histogram(data['steering'], nBin)
    if display:
        center = (bins[:-1] + bins[1:]) * 0.5
        plt.bar(center, hist, width=0.03)
        plt.plot((np.min(data['steering']), np.max(data['steering'])), (samplesPerBin, samplesPerBin))
        plt.title('Data Visualisation')
        plt.xlabel('Steering Angle')
        plt.ylabel('No of Samples')
        plt.show()
    removeindexList = []
    for j in range(nBin):
        binDataList = []
        for i in range(len(data['steering'])):
            if data['steering'][i] >= bins[j] and data['steering'][i] <= bins[j + 1]:
                binDataList.append(i)
        binDataList = shuffle(binDataList)
        binDataList = binDataList[samplesPerBin:]
        removeindexList.extend(binDataList)

    print('Removed Images:', len(removeindexList))
    data.drop(data.index[removeindexList], inplace=True)
    print('Remaining Images:', len(data))
    if display:
        hist, _ = np.histogram(data['steering'], (nBin))
        plt.bar(center, hist, width=0.03)
        plt.plot((np.min(data['steering']), np.max(data['steering'])), (samplesPerBin, samplesPerBin))
        plt.title('Balanced Data')
        plt.xlabel('Steering Angle')
        plt.ylabel('No of Samples')
        plt.show()
    return data

balanced_data = balanceData(data, display=True)
balanced_data.head()
# Out:
# Removed Images: 845
# Remaining Images: 14661
#                               img  steering  throttle
# 0   IMG/Image_170072212088316.jpg   0.03418  -0.41029
# 2  IMG/Image_1700722120998727.jpg   0.03418  -0.52995
# 3  IMG/Image_1700722121011197.jpg   0.03418  -0.52995
# 4  IMG/Image_1700722121019243.jpg   0.03418  -0.52995
# 6  IMG/Image_1700722121068452.jpg   0.03418  -0.63253

# %%
import pandas as pd
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle


#csv_path = 'data.csv'
#data_df = pd.read_csv(csv_path)

data_df = shuffle(balanced_data)

train_df, validation_df = train_test_split(data_df, test_size=0.2)

img_height, img_width = 180, 240

def load_and_preprocess_img1(img_path):
    path = '23Nov959/'+img_path
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.GaussianBlur(img,  (5, 7), 5)
    img = cv2.bitwise_not(img)
    img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 17, -10)
    img = img / 255.0 

    #cv2.imshow('img',img)
    #cv2.waitKey()
    return img

train_images = np.array([load_and_preprocess_img1(path) for path in train_df['img']])
train_steering = np.array(train_df['steering'])
train_throttle = np.array(train_df['throttle'])


validation_images = np.array([load_and_preprocess_img1(path) for path in validation_df['img']])
validation_steering = np.array(validation_df['steering'])
validation_throttle = np.array(validation_df['throttle'])

# %% [markdown]
# # Best Model:

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, History
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dense, MaxPooling2D, BatchNormalization

input_layer = Input(shape=(180, 240, 1))
x = Conv2D(32, (5, 5), strides=(2, 2), activation='elu')(input_layer)
x = MaxPooling2D((2, 2), padding="same")(x)
x = Conv2D(64, (5, 5), strides=(2, 2), activation='relu')(x)
x = MaxPooling2D((2, 2), padding="same")(x)
x = BatchNormalization()(x)
x = Conv2D(64, (5, 5), strides=(2, 2), activation='relu')(x)
x = MaxPooling2D((2, 2), padding="same")(x)
x = Flatten()(x)
x = Dense(100, activation='relu')(x)

steering_output = Dense(1, activation='linear', name='steering_output')(x)

throttle_output = Dense(1, activation='linear', name='throttle_output')(x)

model = Model(inputs=input_layer, outputs=[steering_output, throttle_output])

model.compile(optimizer='adam', loss={'steering_output': 'mse', 'throttle_output': 'mse'})

checkpoint_path = 'model_checkpoints/model_checkpoint_{epoch:02d}.h5'
checkpoint_callback = ModelCheckpoint(checkpoint_path, save_freq='epoch', verbose=1)
history_callback = History()


history = model.fit(train_images, {'steering_output': train_steering, 'throttle_output': train_throttle}, epochs=15,
          validation_data=(validation_images, {'steering_output': validation_steering, 'throttle_output': validation_throttle}),
          callbacks=[checkpoint_callback, history_callback])

loss = model.evaluate(validation_images, {'steering_output': validation_steering, 'throttle_output': validation_throttle})
print(f'Mean Squared Error on Validation Data (Steering): {loss[1]}, Throttle: {loss[2]}')

model.save('23Nov959/23Nov959.h5')
# Out:
# Epoch 1/15
# 366/367 [============================>.] - ETA: 0s - loss: 0.0956 - steering_output_loss: 0.0643 - throttle_output_loss: 0.0313
# Epoch 1: saving model to model_checkpoints\model_checkpoint_01.h5
# 367/367 [==============================] - 23s 60ms/step - loss: 0.0955 - steering_output_loss: 0.0642 - throttle_output_loss: 0.0312 - val_loss: 0.1042 - val_steering_output_loss: 0.0257 - val_throttle_output_loss: 0.0785
# Epoch 2/15
# 366/367 [============================>.] - ETA: 0s - loss: 0.0220 - steering_output_loss: 0.0134 - throttle_output_loss: 0.0086
# Epoch 2: saving model to model_checkpoints\model_checkpoint_02.h5
# 367/367 [==============================] - 21s 58ms/step - loss: 0.0220 - steering_output_loss: 0.0134 - throttle_output_loss: 0.0086 - val_loss: 0.0228 - val_steering_output_loss: 0.0143 - val_throttle_output_loss: 0.0085
# Epoch 3/15
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 6))

plt.subplot(1, 3, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 2)
plt.plot(history.history['steering_output_loss'])
plt.plot(history.history['val_steering_output_loss'])
plt.title('Steering Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 3)
plt.plot(history.history['throttle_output_loss'])
plt.plot(history.history['val_throttle_output_loss'])
plt.title('Throttle Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()
##########################

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 6))

plt.subplot(1, 3, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 2)
plt.plot(history.history['steering_output_loss'])
plt.plot(history.history['val_steering_output_loss'])
plt.title('Steering Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 3)
plt.plot(history.history['throttle_output_loss'])
plt.plot(history.history['val_throttle_output_loss'])
plt.title('Throttle Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 6))

plt.subplot(1, 3, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 2)
plt.plot(history.history['steering_output_loss'])
plt.plot(history.history['val_steering_output_loss'])
plt.title('Steering Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 3)
plt.plot(history.history['throttle_output_loss'])
plt.plot(history.history['val_throttle_output_loss'])
plt.title('Throttle Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Transfer Learning:

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, History
from sklearn.model_selection import train_test_split

# Load CSV data
csv_path = 'data.csv'
df = pd.read_csv(csv_path)

# Split data into training and validation sets
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)

# Image data generator for data augmentation
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Create data generators
train_generator = datagen.flow_from_dataframe(
    dataframe=train_df,
    directory='.',
    x_col='img',
    y_col=['steering', 'throttle'],
    target_size=(180, 240),
    batch_size=32,
    class_mode='raw',
    subset='training'
)

val_generator = datagen.flow_from_dataframe(
    dataframe=val_df,
    directory='.',
    x_col='img',
    y_col=['steering', 'throttle'],
    target_size=(180, 240),
    batch_size=32,
    class_mode='raw',
    subset='validation'
)

# Load pre-trained base model (e.g., MobileNetV2)
base_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(180, 240, 3))

# Freeze the layers of the base model
for layer in base_model.layers:
    layer.trainable = False

# Create your custom model with two heads (steering and throttle)
input_layer = layers.Input(shape=(180, 240, 3))
x = base_model(input_layer)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(100, activation='relu')(x)

# Steering head
steering_output = layers.Dense(1, activation='linear', name='steering_output')(x)

# Throttle head
throttle_output = layers.Dense(1, activation='linear', name='throttle_output')(x)

# Create the model
model = models.Model(inputs=input_layer, outputs=[steering_output, throttle_output])

# Compile the model with separate loss functions for each head
model.compile(optimizer='adam', loss={'steering_output': 'mse', 'throttle_output': 'mse'})

# Callbacks
checkpoint_path = 'model_checkpoints/model_checkpoint_{epoch:02d}.h5'
checkpoint_callback = ModelCheckpoint(checkpoint_path, save_freq='epoch', verbose=1)
history_callback = History()

# Train the model
history = model.fit(train_generator,
                    epochs=10,
                    validation_data=val_generator,
                    callbacks=[checkpoint_callback, history_callback])

# Evaluate the model on the validation set
val_loss = model.evaluate(val_generator)

# Print the MSE for both steering and throttle
print(f'Validation MSE - Steering: {val_loss[1]}, Throttle: {val_loss[2]}')

# Save the trained model
model.save('steering_throttle_model_TL.h5')
# Out:
# Found 1786 validated image filenames.
# Found 111 validated image filenames.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/50
# 56/56 [==============================] - ETA: 0s - loss: 0.6667 - steering_output_loss: 0.4481 - throttle_output_loss: 0.2186
# Epoch 1: saving model to model_checkpoints\model_checkpoint_01.h5
# 56/56 [==============================] - 16s 265ms/step - loss: 0.6667 - steering_output_loss: 0.4481 - throttle_output_loss: 0.2186 - val_loss: 0.3353 - val_steering_output_loss: 0.1648 - val_throttle_output_loss: 0.1705
# Epoch 2/50
# c:\Users\aanas\anaconda3\envs\tens\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 6))

plt.subplot(1, 3, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 2)
plt.plot(history.history['steering_output_loss'])
plt.plot(history.history['val_steering_output_loss'])
plt.title('Steering Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 3)
plt.plot(history.history['throttle_output_loss'])
plt.plot(history.history['val_throttle_output_loss'])
plt.title('Throttle Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, History
from sklearn.model_selection import train_test_split
import cv2

# Load CSV data
csv_path = '23Nov959/data.csv'
df = pd.read_csv(csv_path)

# Split data into training and validation sets
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)

# Image data generator for data augmentation
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Create data generators
def load_and_preprocess_img1(img_path):
    path = '23Nov959/'+img_path
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.GaussianBlur(img,  (5, 7), 5)
    img = cv2.bitwise_not(img)
    img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 17, -10)
    img = img / 255.0 

    # Convert grayscale to three channels
    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    return img

train_generator = datagen.flow_from_dataframe(
    dataframe=train_df,
    directory='23Nov959',
    x_col='img',
    y_col=['steering', 'throttle'],
    target_size=(224, 224),
    batch_size=32,
    class_mode='raw',
    subset='training',
    preprocessing_function=load_and_preprocess_img1
)

val_generator = datagen.flow_from_dataframe(
    dataframe=val_df,
    directory='23Nov959',
    x_col='img',
    y_col=['steering', 'throttle'],
    target_size=(224, 224),
    batch_size=32,
    class_mode='raw',
    subset='validation',
    preprocessing_function=load_and_preprocess_img1
)

# Load pre-trained base model (e.g., MobileNetV2)
base_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the base model
for layer in base_model.layers:
    layer.trainable = False

# Create your custom model with two heads (steering and throttle)
input_layer = layers.Input(shape=(224, 224, 3))
x = base_model(input_layer)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(512, activation='elu')(x)
x = layers.Dense(128, activation='elu')(x)

# Steering head
steering_output = layers.Dense(1, activation='linear', name='steering_output')(x)

# Throttle head
throttle_output = layers.Dense(1, activation='linear', name='throttle_output')(x)

# Create the model
model = models.Model(inputs=input_layer, outputs=[steering_output, throttle_output])

# Compile the model with separate loss functions for each head
model.compile(optimizer='adam', loss={'steering_output': 'mse', 'throttle_output': 'mse'})

# Callbacks
checkpoint_path = 'model_checkpoints/model_checkpoint_{epoch:02d}.h5'
checkpoint_callback = ModelCheckpoint(checkpoint_path, save_freq='epoch', verbose=1)
history_callback = History()

# Train the model
history = model.fit(train_generator,
                    epochs=15,
                    validation_data=val_generator,
                    callbacks=[checkpoint_callback, history_callback])

# Evaluate the model on the validation set
val_loss = model.evaluate(val_generator)

# Print the MSE for both steering and throttle
print(f'Validation MSE - Steering: {val_loss[1]}, Throttle: {val_loss[2]}')

# Save the trained model
model.save('23Nov959/pretrained.h5')
# Out:
# Found 9924 validated image filenames.
# Found 620 validated image filenames.
# Epoch 1/15
# 311/311 [==============================] - ETA: 0s - loss: 0.9569 - steering_output_loss: 0.8265 - throttle_output_loss: 0.1304
# Epoch 1: saving model to model_checkpoints\model_checkpoint_01.h5
# 311/311 [==============================] - 83s 262ms/step - loss: 0.9569 - steering_output_loss: 0.8265 - throttle_output_loss: 0.1304 - val_loss: 0.1614 - val_steering_output_loss: 0.0784 - val_throttle_output_loss: 0.0829
# Epoch 2/15
# c:\Users\aanas\anaconda3\envs\tens\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 311/311 [==============================] - ETA: 0s - loss: 0.1546 - steering_output_loss: 0.0765 - throttle_output_loss: 0.0781
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 6))

plt.subplot(1, 3, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 2)
plt.plot(history.history['steering_output_loss'])
plt.plot(history.history['val_steering_output_loss'])
plt.title('Steering Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 3)
plt.plot(history.history['throttle_output_loss'])
plt.plot(history.history['val_throttle_output_loss'])
plt.title('Throttle Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Best
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, History
from sklearn.model_selection import train_test_split

# Load CSV data
csv_path = 'DATA15/data.csv'
df = pd.read_csv(csv_path)

# Split data into training and validation sets
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)

# Image data generator for data augmentation
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Create data generators
train_generator = datagen.flow_from_dataframe(
    dataframe=train_df,
    directory='DATA15',
    x_col='img',
    y_col=['steering', 'throttle'],
    target_size=(180, 240),
    batch_size=32,
    class_mode='raw',
    subset='training'
)

val_generator = datagen.flow_from_dataframe(
    dataframe=val_df,
    directory='DATA15',
    x_col='img',
    y_col=['steering', 'throttle'],
    target_size=(180, 240),
    batch_size=32,
    class_mode='raw',
    subset='validation'
)

# Load pre-trained base model (e.g., MobileNetV2)
base_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(180, 240, 3))

# Freeze the layers of the base model
for layer in base_model.layers:
    layer.trainable = False

# Create your custom model with two heads (steering and throttle)
input_layer = layers.Input(shape=(180, 240, 3))
x = base_model(input_layer)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(128, activation='relu')(x)

# Steering head
steering_output = layers.Dense(1, activation='linear', name='steering_output')(x)

# Throttle head
throttle_output = layers.Dense(1, activation='linear', name='throttle_output')(x)

# Create the model
model = models.Model(inputs=input_layer, outputs=[steering_output, throttle_output])

# Compile the model with separate loss functions for each head
model.compile(optimizer='adam', loss={'steering_output': 'mse', 'throttle_output': 'mse'})

# Callbacks
checkpoint_path = 'model_checkpoints/model_checkpoint_{epoch:02d}.h5'
checkpoint_callback = ModelCheckpoint(checkpoint_path, save_freq='epoch', verbose=1)
history_callback = History()

# Train the model
history = model.fit(train_generator,
                    epochs=10,
                    validation_data=val_generator,
                    callbacks=[checkpoint_callback, history_callback])

# Evaluate the model on the validation set
val_loss = model.evaluate(val_generator)

# Print the MSE for both steering and throttle
print(f'Validation MSE - Steering: {val_loss[1]}, Throttle: {val_loss[2]}')

# Save the trained model
model.save('steering_throttle_model_TL15.h5')
# Out:
# Found 9444 validated image filenames.
# Found 590 validated image filenames.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/10
# 296/296 [==============================] - ETA: 0s - loss: 0.4026 - steering_output_loss: 0.2133 - throttle_output_loss: 0.1893
# Epoch 1: saving model to model_checkpoints\model_checkpoint_01.h5
# 296/296 [==============================] - 70s 231ms/step - loss: 0.4026 - steering_output_loss: 0.2133 - throttle_output_loss: 0.1893 - val_loss: 0.2854 - val_steering_output_loss: 0.1432 - val_throttle_output_loss: 0.1422
# Epoch 2/10
# c:\Users\aanas\anaconda3\envs\tens\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 6))

plt.subplot(1, 3, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 2)
plt.plot(history.history['steering_output_loss'])
plt.plot(history.history['val_steering_output_loss'])
plt.title('Steering Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 3)
plt.plot(history.history['throttle_output_loss'])
plt.plot(history.history['val_throttle_output_loss'])
plt.title('Throttle Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, History
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam

# Load CSV data
csv_path = 'DATA15/data.csv'
df = pd.read_csv(csv_path)

# Split data into training and validation sets
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)

# Image data generator for data augmentation
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Create data generators
train_generator = datagen.flow_from_dataframe(
    dataframe=train_df,
    directory='.',
    x_col='img',
    y_col=['steering', 'throttle'],
    target_size=(180, 180),
    batch_size=32,
    class_mode='raw',
    subset='training'
)

val_generator = datagen.flow_from_dataframe(
    dataframe=val_df,
    directory='.',
    x_col='img',
    y_col=['steering', 'throttle'],
    target_size=(180, 180),
    batch_size=32,
    class_mode='raw',
    subset='validation'
)

# Load pre-trained base model (e.g., MobileNetV2)
base_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(180, 180, 3))

# Freeze the layers of the base model
trainable_layers = 1
for i in range(len(base_model.layers)):
    if i == len(base_model.layers)-trainable_layers:
        break
    base_model.layers[i].trainable = False
    

# Create your custom model with two heads (steering and throttle)
input_layer = layers.Input(shape=(180, 180, 3))
x = base_model(input_layer)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dense(64, activation='relu')(x)


# Steering head
steering_output = layers.Dense(1, activation='linear', name='steering_output')(x)

# Throttle head
throttle_output = layers.Dense(1, activation='linear', name='throttle_output')(x)

# Create the model
model = models.Model(inputs=input_layer, outputs=[steering_output, throttle_output])

# Compile the model with separate loss functions for each head
adam_optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=adam_optimizer, loss={'steering_output': 'mse', 'throttle_output': 'mse'})

# Callbacks
checkpoint_path = 'model_checkpoints/model_checkpoint_{epoch:02d}.h5'
checkpoint_callback = ModelCheckpoint(checkpoint_path, save_freq='epoch', verbose=1)
history_callback = History()
# Out:
# Found 0 validated image filenames.
# Found 0 validated image filenames.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# c:\Users\aanas\anaconda3\envs\tens\lib\site-packages\keras\src\preprocessing\image.py:1137: UserWarning: Found 2752 invalid image filename(s) in x_col="img". These filename(s) will be ignored.
#   warnings.warn(
# c:\Users\aanas\anaconda3\envs\tens\lib\site-packages\keras\src\preprocessing\image.py:1137: UserWarning: Found 689 invalid image filename(s) in x_col="img". These filename(s) will be ignored.
#   warnings.warn(

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, History
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model  # Added import

# Visualize the model architecture
plot_model(model, to_file='model_architecture.png', show_shapes=True)

# %%
# Good
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, History
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam

# Load CSV data
csv_path = 'DATA15/data.csv'
df = pd.read_csv(csv_path)

# Split data into training and validation sets
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)

# Image data generator for data augmentation
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Create data generators
train_generator = datagen.flow_from_dataframe(
    dataframe=train_df,
    directory='.',
    x_col='img',
    y_col=['steering', 'throttle'],
    target_size=(180, 180),
    batch_size=32,
    class_mode='raw',
    subset='training'
)

val_generator = datagen.flow_from_dataframe(
    dataframe=val_df,
    directory='.',
    x_col='img',
    y_col=['steering', 'throttle'],
    target_size=(180, 180),
    batch_size=32,
    class_mode='raw',
    subset='validation'
)

# Load pre-trained base model (e.g., MobileNetV2)
base_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(180, 180, 3))

# Freeze the layers of the base model
trainable_layers = 1
for i in range(len(base_model.layers)):
    if i == len(base_model.layers)-trainable_layers:
        break
    base_model.layers[i].trainable = False
    

# Create your custom model with two heads (steering and throttle)
input_layer = layers.Input(shape=(180, 180, 3))
x = base_model(input_layer)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dense(64, activation='relu')(x)


# Steering head
steering_output = layers.Dense(1, activation='linear', name='steering_output')(x)

# Throttle head
throttle_output = layers.Dense(1, activation='linear', name='throttle_output')(x)

# Create the model
model = models.Model(inputs=input_layer, outputs=[steering_output, throttle_output])

# Compile the model with separate loss functions for each head
adam_optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=adam_optimizer, loss={'steering_output': 'mse', 'throttle_output': 'mse'})

# Callbacks
checkpoint_path = 'model_checkpoints/model_checkpoint_{epoch:02d}.h5'
checkpoint_callback = ModelCheckpoint(checkpoint_path, save_freq='epoch', verbose=1)
history_callback = History()

# Train the model
history = model.fit(train_generator,
                    epochs=50,
                    validation_data=val_generator,
                    callbacks=[checkpoint_callback, history_callback])

# Evaluate the model on the validation set
val_loss = model.evaluate(val_generator)

# Print the MSE for both steering and throttle
print(f'Validation MSE - Steering: {val_loss[1]}, Throttle: {val_loss[2]}')

# Save the trained model
model.save('steering_throttle_model_TL.h5')
# Out:
# Found 1786 validated image filenames.
# Found 111 validated image filenames.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/50
# 56/56 [==============================] - ETA: 0s - loss: 0.4961 - steering_output_loss: 0.2780 - throttle_output_loss: 0.2181
# Epoch 1: saving model to model_checkpoints\model_checkpoint_01.h5
# 56/56 [==============================] - 13s 200ms/step - loss: 0.4961 - steering_output_loss: 0.2780 - throttle_output_loss: 0.2181 - val_loss: 0.3710 - val_steering_output_loss: 0.1886 - val_throttle_output_loss: 0.1824
# Epoch 2/50
# c:\Users\aanas\anaconda3\envs\tens\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 6))

plt.subplot(1, 3, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 2)
plt.plot(history.history['steering_output_loss'])
plt.plot(history.history['val_steering_output_loss'])
plt.title('Steering Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.subplot(1, 3, 3)
plt.plot(history.history['throttle_output_loss'])
plt.plot(history.history['val_throttle_output_loss'])
plt.title('Throttle Mean Squared Error')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()
